# %%
import os
ld = os.listdir("/home/ducca/CMKD/C2KD/ave/utils/data_new/AVE_Dataset/AVE")
print(len(ld))
# Out:
# 4097

# %%
lst = []
with open("/home/ducca/CMKD/C2KD/ave/utils/data/AVE_Dataset/Annotations.txt", "r", encoding="utf-8") as f:
    # data = f.read()        # đọc toàn bộ nội dung
    # data = f.readlines().split('&')[1] # đọc từng dòng thành list
    data = f.readlines()
    # lst.append(data)
for d in data:
    lst.append(d.split('&')[1])
print(len(lst))
# Out:
# 4144
